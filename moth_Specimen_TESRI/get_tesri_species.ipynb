# %% [markdown]
# ### 資料來源:
# - gbif: [Data-set of Moth Specimen from TESRI](https://www.gbif.org/dataset/f3f25fcf-2930-4cf1-a495-6b31d7fa0252)

# %%
import re
import os
from pathlib import Path
import numpy as np
import pandas as pd
from skimage import io 
from PIL import Image
import urllib.request
import matplotlib.pyplot  as plt
# %matplotlib inline 

dir_data = Path('./data')
dir_meta = Path('./meta')
dir_meta.mkdir(exist_ok=True)

# %% [markdown]
# #### 檢視 "tesri_species_list.csv" 資料概況
# - 物種欄位
#     - 沒有缺值
#     - 種名的空格以"_"呈現
#     - 沒有 sp. 等不確定的種名
#     - !! 沒有重複的種名

# %%
df_tesri_sp = pd.read_csv(dir_meta.joinpath('tesri_species_list.csv'))

df_tesri_sp['Species'] = df_tesri_sp.Species.apply(lambda x : x.replace('_',' '))

print(df_tesri_sp.describe())
print('\nAny NaN in Species column? :　', df_tesri_sp.Species.isnull().all())

df_tesri_sp.query('Species.str.endswith("sp\.")')

print('\n檢視種名的組成，以" "分割種名回傳的長度: ' , {len(sp.split(' ')) for sp in df_tesri_sp.Species.unique()})
# Out:
#           Family  Subfamily     Genus         Species
# count       1868       1868      1868            1868
# unique        47        114      1086            1868
# top     Erebidae  Ennominae  Mythimna  Evonima aperta
# freq         472        229        23               1
#
# Any NaN in Species column? :　 False
#
# 檢視種名的組成，以" "分割種名回傳的長度:  {2, 3}

# %% [markdown]
# #### 讀取gbig "verbatim.txt"

# %%
df_verbatim = pd.read_csv(dir_data.joinpath('verbatim.txt'), sep='\t')
print(f'Number of data : {len(df_verbatim):,d}')
print('Number of columns : ', len(df_verbatim.columns.values))

# drop columns which all value is NaN 
df_verbatim.dropna(axis=1, how='all', inplace=True)
print(f'Number of columns : {len(df_verbatim.columns.values)} (after drop na by columns) ', )

# drop 'scientificName' column which value is NaN 
df_verbatim.dropna(subset=['scientificName'], inplace=True)
print(f'Number of data : {len(df_verbatim):,d} (after drop na by "scientificName" column)')

# drop 'associatedMedia column which value is NaN 
df_verbatim.dropna(subset=['associatedMedia'], inplace=True)
print(f'Number of data : {len(df_verbatim):,d} (after drop na by "associatedMedia" column)')

print('\ncolumns : ', df_verbatim.columns.values)
df_verbatim
# Out:
# Number of data : 109,653
# Number of columns :  219
# Number of columns : 36 (after drop na by columns)
# Number of data : 81,479 (after drop na by "scientificName" column)
# Number of data : 81,229 (after drop na by "associatedMedia" column)
#
# columns :  ['gbifID' 'identifier' 'collectionID' 'institutionCode' 'basisOfRecord'
#  'occurrenceID' 'individualCount' 'sex' 'lifeStage' 'associatedMedia'
#  'associatedReferences' 'eventID' 'parentEventID' 'eventDate'
#  'samplingProtocol' 'sampleSizeValue' 'sampleSizeUnit' 'country'
#  'countryCode' 'county' 'municipality' 'locality' 'verbatimElevation'
#  'decimalLatitude' 'decimalLongitude' 'geodeticDatum' 'identifiedBy'
#  'scientificName' 'kingdom' 'phylum' 'class' 'order' 'family' 'genus'
#  'taxonRank' 'vernacularName']
#             gbifID        identifier      collectionID institutionCode  \
# 0       1934768067  A36-20130606-040  A36-20130606-040           tesri
# 1       1934768377  A36-20130606-041  A36-20130606-041           tesri
# 3       1934767936  A36-20130606-043  A36-20130606-043           tesri
# 4       1934767969  A36-20130606-048  A36-20130606-048           tesri
# 5       1934768183  A36-20130606-049  A36-20130606-049           tesri
# ...            ...               ...               ...             ...
# 109648  2550500679  V38-20191102-067  V38-20191102-067           tesri
# 109649  1934783697  A52-20160704-020  A52-20160704-020           tesri
# 109650  2550500777  V38-20191102-066  V38-20191102-066           tesri
# 109651  2550500710  V38-20191102-065  V38-20191102-065           tesri
# 109652  2550500807  V38-20191102-060  V38-20191102-060           tesri
#
#             basisOfRecord      occurrenceID  individualCount     sex  \
# 0       PreservedSpecimen  A36-20130606-040                1  unknow
# 1       PreservedSpecimen  A36-20130606-041                1  unknow
# 3       PreservedSpecimen  A36-20130606-043                1  unknow
# 4       PreservedSpecimen  A36-20130606-048                1  unknow
# 5       PreservedSpecimen  A36-20130606-049                1  unknow
# ...                   ...               ...              ...     ...
# 109648  PreservedSpecimen  V38-20191102-067                1   femal
# 109649  PreservedSpecimen  A52-20160704-020                1  unknow
# 109650  PreservedSpecimen  V38-20191102-066                1  unknow
# 109651  PreservedSpecimen  V38-20191102-065                1   femal
# 109652  PreservedSpecimen  V38-20191102-060                1  unknow
#
#        lifeStage                                    associatedMedia  ...  \
# 0          adult  http://farm8.staticflickr.com/7429/9554379312_...  ...
# 1          adult  http://farm6.staticflickr.com/5479/9551585327_...  ...
# 3          adult  http://farm4.staticflickr.com/3671/9554375768_...  ...
# 4          adult  http://farm8.staticflickr.com/7446/9554369076_...  ...
# 5          adult  http://farm4.staticflickr.com/3757/9551574537_...  ...
# ...          ...                                                ...  ...
# 109648     adult  https:\/\/live.staticflickr.com\/65535\/493925...  ...
# 109649     adult  https://farm8.staticflickr.com/7741/2902005066...  ...
# 109650     adult  https:\/\/live.staticflickr.com\/65535\/493931...  ...
# 109651     adult  https:\/\/live.staticflickr.com\/65535\/493931...  ...
# 109652     adult  https:\/\/live.staticflickr.com\/65535\/493931...  ...
#
#        identifiedBy               scientificName   kingdom      phylum  \
# 0               施禮正        Chrysaeglia magnifica  Animalia  Arthropoda
# 1               施禮正     Spilarctia nydia werneri  Animalia  Arthropoda
# 3               施禮正              Barsine sauteri  Animalia  Arthropoda
# 4               施禮正          Narosoideus vulpina  Animalia  Arthropoda
# 5               施禮正               Xyleutes strix  Animalia  Arthropoda
# ...             ...                          ...       ...         ...
# 109648          林旭宏       Alcis taiwanovariegata  Animalia  Arthropoda
# 109649          林旭宏        Chrysorabdia vilemani  Animalia  Arthropoda
# 109650          林旭宏       Fascellina chromataria  Animalia  Arthropoda
# 109651          林旭宏  Orthocabera sericea sericea  Animalia  Arthropoda
# 109652          林旭宏   Chiasmia eleonora eleonora  Animalia  Arthropoda
#
#           class        order       family         genus   taxonRank  \
# 0       Insecta  Lepidoptera     Erebidae   Chrysaeglia     species
# 1       Insecta  Lepidoptera     Erebidae    Spilarctia  subspecies
# 3       Insecta  Lepidoptera     Erebidae       Barsine     species
# 4       Insecta  Lepidoptera  Limacodidae   Narosoideus     species
# 5       Insecta  Lepidoptera     Cossidae      Xyleutes     species
# ...         ...          ...          ...           ...         ...
# 109648  Insecta  Lepidoptera  Geometridae         Alcis     species
# 109649  Insecta  Lepidoptera     Erebidae  Chrysorabdia     species
# 109650  Insecta  Lepidoptera  Geometridae    Fascellina     species
# 109651  Insecta  Lepidoptera  Geometridae   Orthocabera  subspecies
# 109652  Insecta  Lepidoptera  Geometridae      Chiasmia  subspecies
#
#        vernacularName
# 0                閃光苔蛾
# 1               黑鬚污燈蛾
# 3               東方葩苔蛾
# 4                狡娜刺蛾
# 5                梟斑蠹蛾
# ...               ...
# 109648        臺灣暗斑霜尺蛾
# 109649           雙帶苔蛾
# 109650          褐缺口尺蛾
# 109651         山茶斜帶尺蛾
# 109652          白帶奇尺蛾
#
# [81229 rows x 36 columns]

# %%
columns_sel = ['gbifID', 'collectionID', 'family', 'genus', 'scientificName', 'taxonRank', 'sex', 'associatedMedia']
df_verbatim_ = df_verbatim[columns_sel]
df_verbatim_['associatedMedia'] = df_verbatim_.associatedMedia.apply(lambda x : str(x).replace('\\', ''))
df_verbatim_
# Out:
# C:\Users\yunghui\anaconda3\envs\pytorch_as\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#             gbifID      collectionID       family         genus  \
# 0       1934768067  A36-20130606-040     Erebidae   Chrysaeglia
# 1       1934768377  A36-20130606-041     Erebidae    Spilarctia
# 3       1934767936  A36-20130606-043     Erebidae       Barsine
# 4       1934767969  A36-20130606-048  Limacodidae   Narosoideus
# 5       1934768183  A36-20130606-049     Cossidae      Xyleutes
# ...            ...               ...          ...           ...
# 109648  2550500679  V38-20191102-067  Geometridae         Alcis
# 109649  1934783697  A52-20160704-020     Erebidae  Chrysorabdia
# 109650  2550500777  V38-20191102-066  Geometridae    Fascellina
# 109651  2550500710  V38-20191102-065  Geometridae   Orthocabera
# 109652  2550500807  V38-20191102-060  Geometridae      Chiasmia
#
#                      scientificName   taxonRank     sex  \
# 0             Chrysaeglia magnifica     species  unknow
# 1          Spilarctia nydia werneri  subspecies  unknow
# 3                   Barsine sauteri     species  unknow
# 4               Narosoideus vulpina     species  unknow
# 5                    Xyleutes strix     species  unknow
# ...                             ...         ...     ...
# 109648       Alcis taiwanovariegata     species   femal
# 109649        Chrysorabdia vilemani     species  unknow
# 109650       Fascellina chromataria     species  unknow
# 109651  Orthocabera sericea sericea  subspecies   femal
# 109652   Chiasmia eleonora eleonora  subspecies  unknow
#
#                                           associatedMedia
# 0       http://farm8.staticflickr.com/7429/9554379312_...
# 1       http://farm6.staticflickr.com/5479/9551585327_...
# 3       http://farm4.staticflickr.com/3671/9554375768_...
# 4       http://farm8.staticflickr.com/7446/9554369076_...
# 5       http://farm4.staticflickr.com/3757/9551574537_...
# ...                                                   ...
# 109648  https://live.staticflickr.com/65535/4939251788...
# 109649  https://farm8.staticflickr.com/7741/2902005066...
# 109650  https://live.staticflickr.com/65535/4939319476...
# 109651  https://live.staticflickr.com/65535/4939319478...
# 109652  https://live.staticflickr.com/65535/4939319492...
#
# [81229 rows x 8 columns]

# %%
df_verbatim_.taxonRank.unique()
# Out:
# array(['species', 'subspecies'], dtype=object)

# %%
df_verbatim_.query('taxonRank == "subspecies"')
# Out:
#             gbifID      collectionID       family        genus  \
# 1       1934768377  A36-20130606-041     Erebidae   Spilarctia
# 7       1934768426  A36-20130606-045     Erebidae        Cyana
# 30      1934762292  A35-20130605-001     Erebidae        Asota
# 31      1934762338  A35-20130605-002     Erebidae        Asota
# 32      1934762258  A35-20130605-003     Erebidae        Asota
# ...            ...               ...          ...          ...
# 109637  1934783716  A52-20160704-011  Geometridae   Ourapteryx
# 109644  2550500635  V38-20191102-062  Geometridae    Hyposidra
# 109647  1934783674  A52-20160704-021     Erebidae        Asota
# 109651  2550500710  V38-20191102-065  Geometridae  Orthocabera
# 109652  2550500807  V38-20191102-060  Geometridae     Chiasmia
#
#                         scientificName   taxonRank     sex  \
# 1             Spilarctia nydia werneri  subspecies  unknow
# 7                  Cyana hamata hamata  subspecies    male
# 30                Asota egens confinis  subspecies  unknow
# 31                Asota plana lacteata  subspecies  unknow
# 32             Asota heliconia zebrina  subspecies  unknow
# ...                                ...         ...     ...
# 109637  Ourapteryx similaria horishana  subspecies  unknow
# 109644         Hyposidra talaca talaca  subspecies    male
# 109647         Asota heliconia zebrina  subspecies  unknow
# 109651     Orthocabera sericea sericea  subspecies   femal
# 109652      Chiasmia eleonora eleonora  subspecies  unknow
#
#                                           associatedMedia
# 1       http://farm6.staticflickr.com/5479/9551585327_...
# 7       http://farm8.staticflickr.com/7313/9554373082_...
# 30      http://farm6.staticflickr.com/5470/9387118195_...
# 31      http://farm4.staticflickr.com/3677/9389892518_...
# 32      http://farm3.staticflickr.com/2834/9389893916_...
# ...                                                   ...
# 109637  https://farm9.staticflickr.com/8121/2956288298...
# 109644  https://live.staticflickr.com/65535/4939252035...
# 109647  https://farm9.staticflickr.com/8483/2901820475...
# 109651  https://live.staticflickr.com/65535/4939319478...
# 109652  https://live.staticflickr.com/65535/4939319492...
#
# [15720 rows x 8 columns]

# %%
df_multimedia = pd.read_csv(dir_data.joinpath('multimedia.txt'), sep='\t')
df_multimedia.dropna(axis=1, how='all', inplace=True)
df_multimedia
# Out:
#            gbifID        type      format  \
# 0      1934756035  StillImage  image/jpeg
# 1      1934756040  StillImage  image/jpeg
# 2      1934756045  StillImage  image/jpeg
# 3      1934756050  StillImage  image/jpeg
# 4      1934756055  StillImage  image/jpeg
# ...           ...         ...         ...
# 78926  2983347367  StillImage  image/jpeg
# 78927  2983348367  StillImage  image/jpeg
# 78928  2983349367  StillImage  image/jpeg
# 78929  2983350362  StillImage  image/jpeg
# 78930  2983350367  StillImage  image/jpeg
#
#                                               identifier
# 0      http://farm3.staticflickr.com/2619/4115988779_...
# 1      http://farm3.staticflickr.com/2588/4116760766_...
# 2      http://farm3.staticflickr.com/2749/4116763040_...
# 3      http://farm3.staticflickr.com/2652/4116759522_...
# 4      http://farm3.staticflickr.com/2757/4115987483_...
# ...                                                  ...
# 78926  https://live.staticflickr.com/65535/5059271493...
# 78927  https://live.staticflickr.com/65535/5059284350...
# 78928  https://live.staticflickr.com/65535/5059271491...
# 78929  https://live.staticflickr.com/65535/5059284432...
# 78930  https://live.staticflickr.com/65535/5059197885...
#
# [78931 rows x 4 columns]

# %% [markdown]
# ### 處理程序

# %% [markdown]
# #### 1. 根據'tesri_species_list.csv'內的物種清單，建立對應的檔案名稱、影像路徑
# - 保存對應的物種名與ID的metadata
#     - key : 科、學名

# %%
df_tesri_sp
# Out:
#             Family        Subfamily         Genus                Species
# 0         Adelidae         Adelinae     Nemophora       Nemophora ahenea
# 1         Adelidae         Adelinae     Nemophora       Nemophora aritai
# 2         Adelidae         Adelinae     Nemophora       Nemophora aurora
# 3         Adelidae         Adelinae     Nemophora    Nemophora fluorites
# 4     Agonoxenidae  Parametriotinae   Lamprystica  Lamprystica purpurata
# ...            ...              ...           ...                    ...
# 1863    Zygaenidae     Chalcosiinae  Hysteroscene   Hysteroscene hyalina
# 1864    Zygaenidae     Chalcosiinae       Pidorus        Pidorus atratus
# 1865    Zygaenidae     Chalcosiinae       Soritia         Soritia azurea
# 1866    Zygaenidae     Chalcosiinae       Soritia          Soritia choui
# 1867    Zygaenidae      Procridinae        Clelea       Clelea formosana
#
# [1868 rows x 4 columns]

# %%
df_tesri_img = df_tesri_sp.merge(df_verbatim_[['collectionID','family','scientificName','sex','associatedMedia']], 
                    left_on=['Family', 'Species'],
                    right_on=['family','scientificName'],
                    how='left' 
                    )[['Family', 'Species', 'collectionID', 'scientificName', 'sex', 'associatedMedia']]
df_tesri_img
# Out:
#            Family           Species      collectionID    scientificName  \
# 0        Adelidae  Nemophora ahenea  A36-20130606-066  Nemophora ahenea
# 1        Adelidae  Nemophora ahenea  A37-20210407-067  Nemophora ahenea
# 2        Adelidae  Nemophora ahenea  V06-20130412-088  Nemophora ahenea
# 3        Adelidae  Nemophora ahenea  A55-20210511-230  Nemophora ahenea
# 4        Adelidae  Nemophora aritai  A48-20160222-078  Nemophora aritai
# ...           ...               ...               ...               ...
# 69908  Zygaenidae     Soritia choui  A64-20170905-001     Soritia choui
# 69909  Zygaenidae     Soritia choui  A64-20170905-003     Soritia choui
# 69910  Zygaenidae     Soritia choui  A64-20210830-003     Soritia choui
# 69911  Zygaenidae     Soritia choui  A64-20210830-001     Soritia choui
# 69912  Zygaenidae  Clelea formosana               NaN               NaN
#
#           sex                                    associatedMedia
# 0      unknow  http://farm8.staticflickr.com/7433/9551556043_...
# 1       femal  https://live.staticflickr.com/65535/5125228124...
# 2      unknow  http://farm8.staticflickr.com/7289/8744067974_...
# 3        male  https://live.staticflickr.com/65535/5153768924...
# 4      unknow  https://farm2.staticflickr.com/1672/2614359891...
# ...       ...                                                ...
# 69908  unknow  https://farm5.staticflickr.com/4494/3677386082...
# 69909  unknow  https://farm5.staticflickr.com/4344/3741338091...
# 69910   femal  https://live.staticflickr.com/65535/5173436643...
# 69911    male  https://live.staticflickr.com/65535/5173501296...
# 69912     NaN                                                NaN
#
# [69913 rows x 6 columns]

# %%
df_tesri_img.describe()
# Out:
#           Family                  Species      collectionID  \
# count      69913                    69913             69768
# unique        47                     1868             69768
# top     Erebidae  Asota heliconia zebrina  V42-20200912-246
# freq       22937                      751                 1
#
#                  scientificName     sex  \
# count                     69768   69768
# unique                     1723       3
# top     Asota heliconia zebrina  unknow
# freq                        751   45694
#
#                                           associatedMedia
# count                                               69768
# unique                                              69764
# top     http://farm8.staticflickr.com/7144/6571918093_...
# freq                                                    2

# %%
count = df_tesri_img.groupby('Species').count().associatedMedia.rename('path_count').reset_index()
df_tesri_img_count = df_tesri_sp.merge(count, left_on='Species', right_on='Species', how='left' )
df_tesri_img_count.to_csv(dir_meta.joinpath('tesri_img_count.csv')) 
df_tesri_img_count
# Out:
#             Family        Subfamily         Genus                Species  \
# 0         Adelidae         Adelinae     Nemophora       Nemophora ahenea
# 1         Adelidae         Adelinae     Nemophora       Nemophora aritai
# 2         Adelidae         Adelinae     Nemophora       Nemophora aurora
# 3         Adelidae         Adelinae     Nemophora    Nemophora fluorites
# 4     Agonoxenidae  Parametriotinae   Lamprystica  Lamprystica purpurata
# ...            ...              ...           ...                    ...
# 1863    Zygaenidae     Chalcosiinae  Hysteroscene   Hysteroscene hyalina
# 1864    Zygaenidae     Chalcosiinae       Pidorus        Pidorus atratus
# 1865    Zygaenidae     Chalcosiinae       Soritia         Soritia azurea
# 1866    Zygaenidae     Chalcosiinae       Soritia          Soritia choui
# 1867    Zygaenidae      Procridinae        Clelea       Clelea formosana
#
#       path_count
# 0              4
# 1              4
# 2              8
# 3              4
# 4              0
# ...          ...
# 1863          22
# 1864          11
# 1865           4
# 1866           5
# 1867           0
#
# [1868 rows x 5 columns]

# %%
print("種名無法匹配的物種數 : ", df_tesri_img.query('scientificName.isnull()').Species.size)
print("有種名，但沒有影像的數量 : ", df_tesri_img.query('scientificName.notnull() and associatedMedia.isnull()').size)
# Out:
# 種名無法匹配的物種數 :  145
# 有種名，但沒有影像的數量 :  0

# %%
df_tesri_img.dropna(subset=['associatedMedia'], inplace=True)
df_tesri_img.reset_index(drop=True, inplace=True)
print("沒有path影像的數量 : ", df_tesri_img.query('associatedMedia.isnull()').size)
# Out:
# 沒有path影像的數量 :  0

# %%
df_tesri_img['associatedMedia'] = df_tesri_img.associatedMedia.apply(lambda str_ : str_.replace('_q.jpg', '.jpg'))
df_tesri_img
# Out:
#            Family           Species      collectionID    scientificName  \
# 0        Adelidae  Nemophora ahenea  A36-20130606-066  Nemophora ahenea
# 1        Adelidae  Nemophora ahenea  A37-20210407-067  Nemophora ahenea
# 2        Adelidae  Nemophora ahenea  V06-20130412-088  Nemophora ahenea
# 3        Adelidae  Nemophora ahenea  A55-20210511-230  Nemophora ahenea
# 4        Adelidae  Nemophora aritai  A48-20160222-078  Nemophora aritai
# ...           ...               ...               ...               ...
# 69763  Zygaenidae     Soritia choui  A64-20170905-002     Soritia choui
# 69764  Zygaenidae     Soritia choui  A64-20170905-001     Soritia choui
# 69765  Zygaenidae     Soritia choui  A64-20170905-003     Soritia choui
# 69766  Zygaenidae     Soritia choui  A64-20210830-003     Soritia choui
# 69767  Zygaenidae     Soritia choui  A64-20210830-001     Soritia choui
#
#           sex                                    associatedMedia
# 0      unknow  http://farm8.staticflickr.com/7433/9551556043_...
# 1       femal  https://live.staticflickr.com/65535/5125228124...
# 2      unknow  http://farm8.staticflickr.com/7289/8744067974_...
# 3        male  https://live.staticflickr.com/65535/5153768924...
# 4      unknow  https://farm2.staticflickr.com/1672/2614359891...
# ...       ...                                                ...
# 69763  unknow  https://farm5.staticflickr.com/4416/2359234584...
# 69764  unknow  https://farm5.staticflickr.com/4494/3677386082...
# 69765  unknow  https://farm5.staticflickr.com/4344/3741338091...
# 69766   femal  https://live.staticflickr.com/65535/5173436643...
# 69767    male  https://live.staticflickr.com/65535/5173501296...
#
# [69768 rows x 6 columns]

# %%
# df_tesri_img[df_tesri_img.associatedMedia.isnull()]
df_tesri_img.query('not associatedMedia.str.endswith("jpg")')
# Out:
# Empty DataFrame
# Columns: [Family, Species, collectionID, scientificName, sex, associatedMedia]
# Index: []

# %%
path_list = df_tesri_img.associatedMedia.values
print(len(path_list))

path_list_ = [path for path in path_list if path.lower().endswith('.jpg')]
print(len(path_list_))

path_list_not = [path for path in path_list if not path.lower().endswith('.jpg')]
print(len(path_list_not))
set(path_list_not)


# path_list_ = [path for path in path_list if str(path).lower().endswith('_q.jpg')]
# print(len(path_list_))

# path_list_not = [path for path in path_list if not str(path).lower().endswith('_q.jpg')]
# print(len(path_list_not))
# Out:
# 69768
# 69768
# 0
# set()

# %%
df_tesri_img.to_csv(dir_meta.joinpath('tesri_img_path.csv'))

# %%
id =  "V36-20180127-160" 
df_tesri_img.query('collectionID == "V04-20130509-159" ')
# Out:
#           Family                 Species      collectionID  \
# 65336  Pyralidae  Endotricha metacuralis  V04-20130509-159
#
#                scientificName     sex  \
# 65336  Endotricha metacuralis  unknow
#
#                                          associatedMedia
# 65336  http://farm4.staticflickr.com/3710/9156300915_...

# %%
with open(dir_meta.joinpath('path_list.txt'), 'w') as file:
    for path in path_list:
        file.write(path + '\t\n' )

# %% [markdown]
# #### 2.根據檔案路徑下載
# - 避免伺服器當掉， 設置sleep?
# - 寫成.py檔，開幾個terminal分流下載
# - 等待設定
#     - 加個try except的迴圈，except發生時 就加入等待時間 每一個連結多一次except，就拉長等待時間，然後訂一個上限 譬如超過5次或10次就放棄那個連結
#
# ##### 見"get_tesri_imgs.py"

# %% [markdown]
# #### 3. 檢查抓取結果

# %%
df_imgs = pd.read_csv("meta/imgs.txt", header=None,  names=['filename'])
df_imgs
# Out:
#                    filename
# 0      A01-20090819-001.jpg
# 1      A01-20090819-002.jpg
# 2      A01-20090819-003.jpg
# 3      A01-20090819-004.jpg
# 4      A01-20090819-005.jpg
# ...                     ...
# 69659  V48-20210905-087.jpg
# 69660  V48-20210905-088.jpg
# 69661  V48-20210905-089.jpg
# 69662  V48-20210905-091.jpg
# 69663  V48-20210905-092.jpg
#
# [69664 rows x 1 columns]

# %% [markdown]
# ### 3.檢查bbox

# %%
df_bboxes = pd.read_csv('../moth_thermal_project/yolov4/moth_all_bboxes_tesri_imgs_YY.csv', index_col=0)
df_bboxes['file'] = df_bboxes.file.apply(lambda path: Path(path).stem)
df_bboxes
# Out:
#                    file                                             bboxes
# 0      A61-20171018-184  67.5809383392334,31.886962890625053,422.491598...
# 1      V33-20170811-245  80.67727088928223,35.87327384948731,408.557653...
# 2      A76-20190409-129  137.29925155639648,98.5918560028076,370.206403...
# 3      V19-20151016-009  71.48327827453616,19.238918304443352,451.12323...
# 4      V48-20210905-042  27.653264999389638,55.21928501129147,450.70738...
# ...                 ...                                                ...
# 69659  V17-20150606-049  47.678565979003885,14.682095527648904,467.0315...
# 69660  V31-20180222-010  88.05942535400393,37.131647109985366,417.37966...
# 69661  V40-20190419-117  63.29630613327025,9.26065826416019,425.2367138...
# 69662  A42-20190129-050  39.69497680664064,34.25918006896973,436.755609...
# 69663  A47-20160425-131  51.35526657104494,18.237154960632303,464.19086...
#
# [69664 rows x 2 columns]

# %%
df_bboxes.query('bboxes.isnull()').file.to_csv(dir_meta.joinpath('bbox_null.csv'))
# Out:
# C:\ProgramData\Anaconda3\envs\pytorch_as\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### 根據類群建立目錄

# %%
df_tesri_sp
# Out:
#             Family        Subfamily         Genus                Species
# 0         Adelidae         Adelinae     Nemophora       Nemophora ahenea
# 1         Adelidae         Adelinae     Nemophora       Nemophora aritai
# 2         Adelidae         Adelinae     Nemophora       Nemophora aurora
# 3         Adelidae         Adelinae     Nemophora    Nemophora fluorites
# 4     Agonoxenidae  Parametriotinae   Lamprystica  Lamprystica purpurata
# ...            ...              ...           ...                    ...
# 1863    Zygaenidae     Chalcosiinae  Hysteroscene   Hysteroscene hyalina
# 1864    Zygaenidae     Chalcosiinae       Pidorus        Pidorus atratus
# 1865    Zygaenidae     Chalcosiinae       Soritia         Soritia azurea
# 1866    Zygaenidae     Chalcosiinae       Soritia          Soritia choui
# 1867    Zygaenidae      Procridinae        Clelea       Clelea formosana
#
# [1868 rows x 4 columns]

# %%
df_bboxes = pd.read_csv(dir_meta.joinpath('moth_all_bboxes_tersi_imgs_forYY.csv'), index_col=0)
df_file = df_bboxes.file.apply(lambda path: Path(path).stem)
df_file
# Out:
# 0        A61-20171018-184
# 1        V33-20170811-245
# 2        A76-20190409-129
# 3        V19-20151016-009
# 4        V48-20210905-042
#                ...
# 69659    V17-20150606-049
# 69660    V31-20180222-010
# 69661    V40-20190419-117
# 69662    A42-20190129-050
# 69663    A47-20160425-131
# Name: file, Length: 69664, dtype: object

# %%
df_tesri_img = pd.read_csv(dir_meta.joinpath('tesri_img_path.csv'), index_col=0)
df_tesri_img_ = df_tesri_img.merge(df_file, 
                    left_on='collectionID',
                    right_on='file',
                    how='right' 
                   )
df_tesri_img_
# Out:
#            Family           Species      collectionID    scientificName  \
# 0        Adelidae  Nemophora ahenea  A36-20130606-066  Nemophora ahenea
# 1        Adelidae  Nemophora ahenea  A37-20210407-067  Nemophora ahenea
# 2        Adelidae  Nemophora ahenea  V06-20130412-088  Nemophora ahenea
# 3        Adelidae  Nemophora ahenea  A55-20210511-230  Nemophora ahenea
# 4        Adelidae  Nemophora aritai  A48-20160222-078  Nemophora aritai
# ...           ...               ...               ...               ...
# 69659  Zygaenidae     Soritia choui  A64-20170905-002     Soritia choui
# 69660  Zygaenidae     Soritia choui  A64-20170905-001     Soritia choui
# 69661  Zygaenidae     Soritia choui  A64-20170905-003     Soritia choui
# 69662  Zygaenidae     Soritia choui  A64-20210830-003     Soritia choui
# 69663  Zygaenidae     Soritia choui  A64-20210830-001     Soritia choui
#
#           sex                                    associatedMedia  \
# 0      unknow  http://farm8.staticflickr.com/7433/9551556043_...
# 1       femal  https://live.staticflickr.com/65535/5125228124...
# 2      unknow  http://farm8.staticflickr.com/7289/8744067974_...
# 3        male  https://live.staticflickr.com/65535/5153768924...
# 4      unknow  https://farm2.staticflickr.com/1672/2614359891...
# ...       ...                                                ...
# 69659  unknow  https://farm5.staticflickr.com/4416/2359234584...
# 69660  unknow  https://farm5.staticflickr.com/4494/3677386082...
# 69661  unknow  https://farm5.staticflickr.com/4344/3741338091...
# 69662   femal  https://live.staticflickr.com/65535/5173436643...
# 69663    male  https://live.staticflickr.com/65535/5173501296...
#
#                    file
# 0      A36-20130606-066
# 1      A37-20210407-067
# 2      V06-20130412-088
# 3      A55-20210511-230
# 4      A48-20160222-078
# ...                 ...
# 69659  A64-20170905-002
# 69660  A64-20170905-001
# 69661  A64-20170905-003
# 69662  A64-20210830-003
# 69663  A64-20210830-001
#
# [69664 rows x 7 columns]

# %%
df_tesri_img_ = df_tesri_img_.merge(df_tesri_sp,
                                    left_on=['Family','Species'],
                                    right_on=['Family','Species'],
                                    how='left'
                    )
df_tesri_filelist_taxon = df_tesri_img_[['Family','Subfamily','Genus','Species', 'file']].reset_index(drop=True)
df_tesri_filelist_taxon.to_csv(dir_meta.joinpath('tesri_filelist_taxon.csv'))
# Out:
#            Family     Subfamily      Genus           Species              file
# 0        Adelidae      Adelinae  Nemophora  Nemophora ahenea  A36-20130606-066
# 1        Adelidae      Adelinae  Nemophora  Nemophora ahenea  A37-20210407-067
# 2        Adelidae      Adelinae  Nemophora  Nemophora ahenea  V06-20130412-088
# 3        Adelidae      Adelinae  Nemophora  Nemophora ahenea  A55-20210511-230
# 4        Adelidae      Adelinae  Nemophora  Nemophora aritai  A48-20160222-078
# ...           ...           ...        ...               ...               ...
# 69659  Zygaenidae  Chalcosiinae    Soritia     Soritia choui  A64-20170905-002
# 69660  Zygaenidae  Chalcosiinae    Soritia     Soritia choui  A64-20170905-001
# 69661  Zygaenidae  Chalcosiinae    Soritia     Soritia choui  A64-20170905-003
# 69662  Zygaenidae  Chalcosiinae    Soritia     Soritia choui  A64-20210830-003
# 69663  Zygaenidae  Chalcosiinae    Soritia     Soritia choui  A64-20210830-001
#
# [69664 rows x 5 columns]

# %%
df_tesri_filelist_taxon = pd.read_csv(dir_meta.joinpath('tesri_filelist_taxon.csv'), index_col=0)
df_tesri_filelist_taxon
# Out:
#            Family     Subfamily      Genus           Species              file
# 0        Adelidae      Adelinae  Nemophora  Nemophora ahenea  A36-20130606-066
# 1        Adelidae      Adelinae  Nemophora  Nemophora ahenea  A37-20210407-067
# 2        Adelidae      Adelinae  Nemophora  Nemophora ahenea  V06-20130412-088
# 3        Adelidae      Adelinae  Nemophora  Nemophora ahenea  A55-20210511-230
# 4        Adelidae      Adelinae  Nemophora  Nemophora aritai  A48-20160222-078
# ...           ...           ...        ...               ...               ...
# 69659  Zygaenidae  Chalcosiinae    Soritia     Soritia choui  A64-20170905-002
# 69660  Zygaenidae  Chalcosiinae    Soritia     Soritia choui  A64-20170905-001
# 69661  Zygaenidae  Chalcosiinae    Soritia     Soritia choui  A64-20170905-003
# 69662  Zygaenidae  Chalcosiinae    Soritia     Soritia choui  A64-20210830-003
# 69663  Zygaenidae  Chalcosiinae    Soritia     Soritia choui  A64-20210830-001
#
# [69664 rows x 5 columns]

# %%
df_filelist_count = df_tesri_filelist_taxon.groupby(by=['Family', 'Subfamily']).count().file.sort_values(ascending=False)
df_filelist_count
# Out:
# Family          Subfamily
# Geometridae     Ennominae        13100
# Erebidae        Arctiinae         6647
#                 Erebinae          5877
# Noctuidae       Noctuinae         4509
# Crambidae       Spilomelinae      3383
#                                  ...
# Hyblaeidae      Hypocalinae          3
# Lecithoceridae  Unassigned           3
# Pterophoridae   Ochyroticinae        2
# Papilionidae    Papilioninae         2
# Sesiidae        Sesiinae             2
# Name: file, Length: 120, dtype: int64

# %%
df_filelist_count[df_filelist_count > 2000]
# Out:
# Family       Subfamily
# Geometridae  Ennominae       13100
# Erebidae     Arctiinae        6647
#              Erebinae         5877
# Noctuidae    Noctuinae        4509
# Crambidae    Spilomelinae     3383
# Erebidae     Lymantriinae     3171
# Name: file, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ### 檢查問題影像

# %%
dir_broken = Path('broken images')
file_broken= [path.stem.split('_cropped')[0] for path in dir_broken.glob('*.png')]
print(len(file_broken))
# Out:
# 2

# %%
# 檢查兩張破損的影像在原始flickr連結是正常的
# 抓到的原始圖檔比flickr完整

for file in file_broken:
    link =  df_verbatim_.query('collectionID==@file').associatedMedia.values[0]
    img = io.imread(link)
    # io.imshow(img)
    Image.fromarray(img).show()
    ;

# %%
# 檢查bbox看似也沒問題
df_bboxes = pd.read_csv('meta/moth_all_bboxes_tersi_imgs_forYY.csv', index_col=0)

df_bboxes_img_broken = df_bboxes.query(
    'file.str.contains(@file_broken[0]) or file.str.contains(@file_broken[1])'
    )

df_bboxes_img_broken.to_csv('../moth_thermal_project/yolov4/moth_all_bboxes_img_broken.csv')
df_bboxes_img_broken = pd.read_csv('../moth_thermal_project/yolov4/moth_all_bboxes_img_broken.csv', index_col=0)
df_bboxes_img_broken
# Out:
#                                                     file  \
# 12421  ../../Moth_Specimen_TESRI/tesri_imgs_YY/V14-20...
# 50561  ../../Moth_Specimen_TESRI/tesri_imgs_YY/V42-20...
#
#                                                   bboxes
# 12421  0,42.571967124938936,491.4109706878662,312.318...
# 50561  74.3729591369629,73.46022510528566,440.9010887...

# %%
df_bboxes.file = df_bboxes.file.str.replace('tesri_imgs_forYY', 'tesri_imgs_YY')
df_bboxes.to_csv('meta/moth_all_bboxes_tersi_imgs_forYY.csv')
